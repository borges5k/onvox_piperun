# %%
import requests

r = requests.post("https://corretoraviver.ras.uccpbx.com/openapi/v1.0/get_token",
                  json={"username": "caP1zt2p8PVosW28jyOLafYQxy9z6tN9",
                        "password": "UhR0ZiRHeCChSf4ubOE8U6WE5vKP4uvi"},
                  headers={"User-Agent": "OpenAPI"})

print("Status:", r.status_code)
print("Body  :", r.text)
# Out:
# Status: 200
# Body  : {"errcode":0,"errmsg":"SUCCESS","access_token_expire_time":1800,"access_token":"6YwQkWbBvGkQfoPKW7xEUn5gj5v7MmoA","refresh_token_expire_time":86400,"refresh_token":"7gR5q7nSgSXg3WrVX3pKVZDtjbAOYQfG","ys_id":""}

# %%
import requests
print(requests.get("https://api4.ipify.org").text)
# Out:
# 189.50.138.97
